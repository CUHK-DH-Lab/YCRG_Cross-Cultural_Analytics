# %%
import pandas as pd

# %%
# Read the CSV file
df = pd.read_csv('MetaLatin.csv')

# Drop duplicate rows
df.drop_duplicates(inplace=True)

# Write the deduplicated dataframe to a new CSV file
df.to_csv('MetaFrench_fl.csv', index=False)
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_59664\1267491267.py:2: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('MetaFrench.csv')
