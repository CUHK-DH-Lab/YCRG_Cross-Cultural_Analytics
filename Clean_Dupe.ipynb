# %%
import pandas as pd

# %%
# Load the CSV file generated by dedupe
df = pd.read_csv('MetaLatin_op.csv')
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_23660\2907044143.py:2: DtypeWarning: Columns (38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('MetaLatin_op.csv')

# %%
# Drop duplicates based on the 'id' column
df.drop_duplicates(subset='Cluster ID', inplace=True)

# %%
# Save the clean list of documents to a new CSV file
df.to_csv('MetaLatin_op_c.csv', index=False)
