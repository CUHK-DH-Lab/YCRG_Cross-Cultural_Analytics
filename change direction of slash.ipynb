# %%
# Read the file content
with open('E:\Datasets\Hathi_Catalogue\dfs\df_path_list_5.txt', 'r') as f:
    content = f.read()

# Replace all backslashes with forward slashes
content = content.replace('\\', '/')

# Write the modified content back to the file
with open('E:\Datasets\Hathi_Catalogue\dfs\df_path_list_5.txt', 'w') as f:
    f.write(content)
