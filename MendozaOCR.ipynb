# %% [markdown]
# <a href="https://colab.research.google.com/github/CUHK-DH-Lab/CUHK-DH-Lab.github.io/blob/main/MendozaOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import fitz  # PyMuPDF
import os

# Define the PDF file path
pdf_file = 'bub_gb_6QiHhHwp8MMC.pdf'

# Create a directory to save the extracted images
output_folder = 'extracted_images_for_ocr'
os.makedirs(output_folder, exist_ok=True)

print(f"Opening PDF: {pdf_file}")

try:
    # Open the PDF document
    doc = fitz.open(pdf_file)

    # Iterate through each page
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)  # Load a page

        # Set a high DPI for rendering to ensure high quality for OCR
        # A common DPI for OCR is 300, but you can go higher if needed (e.g., 600)
        dpi = 300
        zoom_x = dpi / 72.0  # horizontal zoom
        zoom_y = dpi / 72.0  # vertical zoom
        mat = fitz.Matrix(zoom_x, zoom_y)  # zoom factor

        pix = page.get_pixmap(matrix=mat)  # Render page to an image

        # Define the output image file path
        output_image_path = os.path.join(output_folder, f"page_{page_num+1:04d}.png")

        # Save the image
        pix.save(output_image_path)
        print(f"Saved {output_image_path}")

    doc.close()
    print(f"Image extraction complete. Images saved to '{output_folder}' directory.")

except FileNotFoundError:
    print(f"Error: The file '{pdf_file}' was not found. Please make sure it's uploaded or correctly path-configured.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Opening PDF: bub_gb_6QiHhHwp8MMC.pdf
# Saved extracted_images_for_ocr/page_0001.png
# Saved extracted_images_for_ocr/page_0002.png
# Saved extracted_images_for_ocr/page_0003.png
# Saved extracted_images_for_ocr/page_0004.png
# Saved extracted_images_for_ocr/page_0005.png
# Saved extracted_images_for_ocr/page_0006.png
# Saved extracted_images_for_ocr/page_0007.png
# Saved extracted_images_for_ocr/page_0008.png
# Saved extracted_images_for_ocr/page_0009.png
# Saved extracted_images_for_ocr/page_0010.png
# Saved extracted_images_for_ocr/page_0011.png
# Saved extracted_images_for_ocr/page_0012.png
# Saved extracted_images_for_ocr/page_0013.png
# Saved extracted_images_for_ocr/page_0014.png
# Saved extracted_images_for_ocr/page_0015.png
# Saved extracted_images_for_ocr/page_0016.png
# Saved extracted_images_for_ocr/page_0017.png
# Saved extracted_images_for_ocr/page_0018.png
# Saved extracted_images_for_ocr/page_0019.png
# Saved extracted_images_for_ocr/page_0020.png
# Saved extracted_images_for_ocr/page_0021.png
# Saved extracted_images_for_ocr/page_0022.png
# Saved extracted_images_for_ocr/page_0023.png
# Saved extracted_images_for_ocr/page_0024.png
# Saved extracted_images_for_ocr/page_0025.png
# Saved extracted_images_for_ocr/page_0026.png
# Saved extracted_images_for_ocr/page_0027.png
# Saved extracted_images_for_ocr/page_0028.png
# Saved extracted_images_for_ocr/page_0029.png
# Saved extracted_images_for_ocr/page_0030.png
# Saved extracted_images_for_ocr/page_0031.png
# Saved extracted_images_for_ocr/page_0032.png
# Saved extracted_images_for_ocr/page_0033.png
# Saved extracted_images_for_ocr/page_0034.png
# Saved extracted_images_for_ocr/page_0035.png
# Saved extracted_images_for_ocr/page_0036.png
# Saved extracted_images_for_ocr/page_0037.png
# Saved extracted_images_for_ocr/page_0038.png
# Saved extracted_images_for_ocr/page_0039.png
# Saved extracted_images_for_ocr/page_0040.png
# Saved extracted_images_for_ocr/page_0041.png
# Saved extracted_images_for_ocr/page_0042.png
# Saved extracted_images_for_ocr/page_0043.png
# Saved extracted_images_for_ocr/page_0044.png
# Saved extracted_images_for_ocr/page_0045.png
# Saved extracted_images_for_ocr/page_0046.png
# Saved extracted_images_for_ocr/page_0047.png
# Saved extracted_images_for_ocr/page_0048.png
# Saved extracted_images_for_ocr/page_0049.png
# Saved extracted_images_for_ocr/page_0050.png
# Saved extracted_images_for_ocr/page_0051.png
# Saved extracted_images_for_ocr/page_0052.png
# Saved extracted_images_for_ocr/page_0053.png
# Saved extracted_images_for_ocr/page_0054.png
# Saved extracted_images_for_ocr/page_0055.png
# Saved extracted_images_for_ocr/page_0056.png
# Saved extracted_images_for_ocr/page_0057.png
# Saved extracted_images_for_ocr/page_0058.png
# Saved extracted_images_for_ocr/page_0059.png
# Saved extracted_images_for_ocr/page_0060.png
# Saved extracted_images_for_ocr/page_0061.png
# Saved extracted_images_for_ocr/page_0062.png
# Saved extracted_images_for_ocr/page_0063.png
# Saved extracted_images_for_ocr/page_0064.png
# Saved extracted_images_for_ocr/page_0065.png
# Saved extracted_images_for_ocr/page_0066.png
# Saved extracted_images_for_ocr/page_0067.png
# Saved extracted_images_for_ocr/page_0068.png
# Saved extracted_images_for_ocr/page_0069.png
# Saved extracted_images_for_ocr/page_0070.png
# Saved extracted_images_for_ocr/page_0071.png
# Saved extracted_images_for_ocr/page_0072.png
# Saved extracted_images_for_ocr/page_0073.png
# Saved extracted_images_for_ocr/page_0074.png
# Saved extracted_images_for_ocr/page_0075.png
# Saved extracted_images_for_ocr/page_0076.png
# Saved extracted_images_for_ocr/page_0077.png
# Saved extracted_images_for_ocr/page_0078.png
# Saved extracted_images_for_ocr/page_0079.png
# Saved extracted_images_for_ocr/page_0080.png
# Saved extracted_images_for_ocr/page_0081.png
# Saved extracted_images_for_ocr/page_0082.png
# Saved extracted_images_for_ocr/page_0083.png
# Saved extracted_images_for_ocr/page_0084.png
# Saved extracted_images_for_ocr/page_0085.png
# Saved extracted_images_for_ocr/page_0086.png
# Saved extracted_images_for_ocr/page_0087.png
# Saved extracted_images_for_ocr/page_0088.png
# Saved extracted_images_for_ocr/page_0089.png
# Saved extracted_images_for_ocr/page_0090.png
# Saved extracted_images_for_ocr/page_0091.png
# Saved extracted_images_for_ocr/page_0092.png
# Saved extracted_images_for_ocr/page_0093.png
# Saved extracted_images_for_ocr/page_0094.png
# Saved extracted_images_for_ocr/page_0095.png
# Saved extracted_images_for_ocr/page_0096.png
# Saved extracted_images_for_ocr/page_0097.png
# Saved extracted_images_for_ocr/page_0098.png
# Saved extracted_images_for_ocr/page_0099.png
# Saved extracted_images_for_ocr/page_0100.png
# Saved extracted_images_for_ocr/page_0101.png
# Saved extracted_images_for_ocr/page_0102.png
# Saved extracted_images_for_ocr/page_0103.png
# Saved extracted_images_for_ocr/page_0104.png
# Saved extracted_images_for_ocr/page_0105.png
# Saved extracted_images_for_ocr/page_0106.png
# Saved extracted_images_for_ocr/page_0107.png
# Saved extracted_images_for_ocr/page_0108.png
# Saved extracted_images_for_ocr/page_0109.png
# Saved extracted_images_for_ocr/page_0110.png
# Saved extracted_images_for_ocr/page_0111.png
# Saved extracted_images_for_ocr/page_0112.png
# Saved extracted_images_for_ocr/page_0113.png
# Saved extracted_images_for_ocr/page_0114.png
# Saved extracted_images_for_ocr/page_0115.png
# Saved extracted_images_for_ocr/page_0116.png
# Saved extracted_images_for_ocr/page_0117.png
# Saved extracted_images_for_ocr/page_0118.png
# Saved extracted_images_for_ocr/page_0119.png
# Saved extracted_images_for_ocr/page_0120.png
# Saved extracted_images_for_ocr/page_0121.png
# Saved extracted_images_for_ocr/page_0122.png
# Saved extracted_images_for_ocr/page_0123.png
# Saved extracted_images_for_ocr/page_0124.png
# Saved extracted_images_for_ocr/page_0125.png
# Saved extracted_images_for_ocr/page_0126.png
# Saved extracted_images_for_ocr/page_0127.png
# Saved extracted_images_for_ocr/page_0128.png
# Saved extracted_images_for_ocr/page_0129.png
# Saved extracted_images_for_ocr/page_0130.png
# Saved extracted_images_for_ocr/page_0131.png
# Saved extracted_images_for_ocr/page_0132.png
# Saved extracted_images_for_ocr/page_0133.png
# Saved extracted_images_for_ocr/page_0134.png
# Saved extracted_images_for_ocr/page_0135.png
# Saved extracted_images_for_ocr/page_0136.png
# Saved extracted_images_for_ocr/page_0137.png
# Saved extracted_images_for_ocr/page_0138.png
# Saved extracted_images_for_ocr/page_0139.png
# Saved extracted_images_for_ocr/page_0140.png
# Saved extracted_images_for_ocr/page_0141.png
# Saved extracted_images_for_ocr/page_0142.png
# Saved extracted_images_for_ocr/page_0143.png
# Saved extracted_images_for_ocr/page_0144.png
# Saved extracted_images_for_ocr/page_0145.png
# Saved extracted_images_for_ocr/page_0146.png
# Saved extracted_images_for_ocr/page_0147.png
# Saved extracted_images_for_ocr/page_0148.png
# Saved extracted_images_for_ocr/page_0149.png
# Saved extracted_images_for_ocr/page_0150.png
# Saved extracted_images_for_ocr/page_0151.png
# Saved extracted_images_for_ocr/page_0152.png
# Saved extracted_images_for_ocr/page_0153.png
# Saved extracted_images_for_ocr/page_0154.png
# Saved extracted_images_for_ocr/page_0155.png
# Saved extracted_images_for_ocr/page_0156.png
# Saved extracted_images_for_ocr/page_0157.png
# Saved extracted_images_for_ocr/page_0158.png
# Saved extracted_images_for_ocr/page_0159.png
# Saved extracted_images_for_ocr/page_0160.png
# Saved extracted_images_for_ocr/page_0161.png
# Saved extracted_images_for_ocr/page_0162.png
# Saved extracted_images_for_ocr/page_0163.png
# Saved extracted_images_for_ocr/page_0164.png
# Saved extracted_images_for_ocr/page_0165.png
# Saved extracted_images_for_ocr/page_0166.png
# Saved extracted_images_for_ocr/page_0167.png
# Saved extracted_images_for_ocr/page_0168.png
# Saved extracted_images_for_ocr/page_0169.png
# Saved extracted_images_for_ocr/page_0170.png
# Saved extracted_images_for_ocr/page_0171.png
# Saved extracted_images_for_ocr/page_0172.png
# Saved extracted_images_for_ocr/page_0173.png
# Saved extracted_images_for_ocr/page_0174.png
# Saved extracted_images_for_ocr/page_0175.png
# Saved extracted_images_for_ocr/page_0176.png
# Saved extracted_images_for_ocr/page_0177.png
# Saved extracted_images_for_ocr/page_0178.png
# Saved extracted_images_for_ocr/page_0179.png
# Saved extracted_images_for_ocr/page_0180.png
# Saved extracted_images_for_ocr/page_0181.png
# Saved extracted_images_for_ocr/page_0182.png
# Saved extracted_images_for_ocr/page_0183.png
# Saved extracted_images_for_ocr/page_0184.png
# Saved extracted_images_for_ocr/page_0185.png
# Saved extracted_images_for_ocr/page_0186.png
# Saved extracted_images_for_ocr/page_0187.png
# Saved extracted_images_for_ocr/page_0188.png
# Saved extracted_images_for_ocr/page_0189.png
# Saved extracted_images_for_ocr/page_0190.png
# Saved extracted_images_for_ocr/page_0191.png
# Saved extracted_images_for_ocr/page_0192.png
# Saved extracted_images_for_ocr/page_0193.png
# Saved extracted_images_for_ocr/page_0194.png
# Saved extracted_images_for_ocr/page_0195.png
# Saved extracted_images_for_ocr/page_0196.png
# Saved extracted_images_for_ocr/page_0197.png
# Saved extracted_images_for_ocr/page_0198.png
# Saved extracted_images_for_ocr/page_0199.png
# Saved extracted_images_for_ocr/page_0200.png
# Saved extracted_images_for_ocr/page_0201.png
# Saved extracted_images_for_ocr/page_0202.png
# Saved extracted_images_for_ocr/page_0203.png
# Saved extracted_images_for_ocr/page_0204.png
# Saved extracted_images_for_ocr/page_0205.png
# Saved extracted_images_for_ocr/page_0206.png
# Saved extracted_images_for_ocr/page_0207.png
# Saved extracted_images_for_ocr/page_0208.png
# Saved extracted_images_for_ocr/page_0209.png
# Saved extracted_images_for_ocr/page_0210.png
# Saved extracted_images_for_ocr/page_0211.png
# Saved extracted_images_for_ocr/page_0212.png
# Saved extracted_images_for_ocr/page_0213.png
# Saved extracted_images_for_ocr/page_0214.png
# Saved extracted_images_for_ocr/page_0215.png
# Saved extracted_images_for_ocr/page_0216.png
# Saved extracted_images_for_ocr/page_0217.png
# Saved extracted_images_for_ocr/page_0218.png
# Saved extracted_images_for_ocr/page_0219.png
# Saved extracted_images_for_ocr/page_0220.png
# Saved extracted_images_for_ocr/page_0221.png
# Saved extracted_images_for_ocr/page_0222.png
# Saved extracted_images_for_ocr/page_0223.png
# Saved extracted_images_for_ocr/page_0224.png
# Saved extracted_images_for_ocr/page_0225.png
# Saved extracted_images_for_ocr/page_0226.png
# Saved extracted_images_for_ocr/page_0227.png
# Saved extracted_images_for_ocr/page_0228.png
# Saved extracted_images_for_ocr/page_0229.png
# Saved extracted_images_for_ocr/page_0230.png
# Saved extracted_images_for_ocr/page_0231.png
# Saved extracted_images_for_ocr/page_0232.png
# Saved extracted_images_for_ocr/page_0233.png
# Saved extracted_images_for_ocr/page_0234.png
# Saved extracted_images_for_ocr/page_0235.png
# Saved extracted_images_for_ocr/page_0236.png
# Saved extracted_images_for_ocr/page_0237.png
# Saved extracted_images_for_ocr/page_0238.png
# Saved extracted_images_for_ocr/page_0239.png
# Saved extracted_images_for_ocr/page_0240.png
# Saved extracted_images_for_ocr/page_0241.png
# Saved extracted_images_for_ocr/page_0242.png
# Saved extracted_images_for_ocr/page_0243.png
# Saved extracted_images_for_ocr/page_0244.png
# Saved extracted_images_for_ocr/page_0245.png
# Saved extracted_images_for_ocr/page_0246.png
# Saved extracted_images_for_ocr/page_0247.png
# Saved extracted_images_for_ocr/page_0248.png
# Saved extracted_images_for_ocr/page_0249.png
# Saved extracted_images_for_ocr/page_0250.png
# Saved extracted_images_for_ocr/page_0251.png
# Saved extracted_images_for_ocr/page_0252.png
# Saved extracted_images_for_ocr/page_0253.png
# Saved extracted_images_for_ocr/page_0254.png
# Saved extracted_images_for_ocr/page_0255.png
# Saved extracted_images_for_ocr/page_0256.png
# Saved extracted_images_for_ocr/page_0257.png
# Saved extracted_images_for_ocr/page_0258.png
# Saved extracted_images_for_ocr/page_0259.png
# Saved extracted_images_for_ocr/page_0260.png
# Saved extracted_images_for_ocr/page_0261.png
# Saved extracted_images_for_ocr/page_0262.png
# Saved extracted_images_for_ocr/page_0263.png
# Saved extracted_images_for_ocr/page_0264.png
# Saved extracted_images_for_ocr/page_0265.png
# Saved extracted_images_for_ocr/page_0266.png
# Saved extracted_images_for_ocr/page_0267.png
# Saved extracted_images_for_ocr/page_0268.png
# Saved extracted_images_for_ocr/page_0269.png
# Saved extracted_images_for_ocr/page_0270.png
# Saved extracted_images_for_ocr/page_0271.png
# Saved extracted_images_for_ocr/page_0272.png
# Saved extracted_images_for_ocr/page_0273.png
# Saved extracted_images_for_ocr/page_0274.png
# Saved extracted_images_for_ocr/page_0275.png
# Saved extracted_images_for_ocr/page_0276.png
# Saved extracted_images_for_ocr/page_0277.png
# Saved extracted_images_for_ocr/page_0278.png
# Saved extracted_images_for_ocr/page_0279.png
# Saved extracted_images_for_ocr/page_0280.png
# Saved extracted_images_for_ocr/page_0281.png
# Saved extracted_images_for_ocr/page_0282.png
# Saved extracted_images_for_ocr/page_0283.png
# Saved extracted_images_for_ocr/page_0284.png
# Saved extracted_images_for_ocr/page_0285.png
# Saved extracted_images_for_ocr/page_0286.png
# Saved extracted_images_for_ocr/page_0287.png
# Saved extracted_images_for_ocr/page_0288.png
# Saved extracted_images_for_ocr/page_0289.png
# Saved extracted_images_for_ocr/page_0290.png
# Saved extracted_images_for_ocr/page_0291.png
# Saved extracted_images_for_ocr/page_0292.png
# Saved extracted_images_for_ocr/page_0293.png
# Saved extracted_images_for_ocr/page_0294.png
# Saved extracted_images_for_ocr/page_0295.png
# Saved extracted_images_for_ocr/page_0296.png
# Saved extracted_images_for_ocr/page_0297.png
# Saved extracted_images_for_ocr/page_0298.png
# Saved extracted_images_for_ocr/page_0299.png
# Saved extracted_images_for_ocr/page_0300.png
# Saved extracted_images_for_ocr/page_0301.png
# Saved extracted_images_for_ocr/page_0302.png
# Saved extracted_images_for_ocr/page_0303.png
# Saved extracted_images_for_ocr/page_0304.png
# Saved extracted_images_for_ocr/page_0305.png
# Saved extracted_images_for_ocr/page_0306.png
# Saved extracted_images_for_ocr/page_0307.png
# Saved extracted_images_for_ocr/page_0308.png
# Saved extracted_images_for_ocr/page_0309.png
# Saved extracted_images_for_ocr/page_0310.png
# Saved extracted_images_for_ocr/page_0311.png
# Saved extracted_images_for_ocr/page_0312.png
# Saved extracted_images_for_ocr/page_0313.png
# Saved extracted_images_for_ocr/page_0314.png
# Saved extracted_images_for_ocr/page_0315.png
# Saved extracted_images_for_ocr/page_0316.png
# Saved extracted_images_for_ocr/page_0317.png
# Saved extracted_images_for_ocr/page_0318.png
# Saved extracted_images_for_ocr/page_0319.png
# Saved extracted_images_for_ocr/page_0320.png
# Saved extracted_images_for_ocr/page_0321.png
# Saved extracted_images_for_ocr/page_0322.png
# Saved extracted_images_for_ocr/page_0323.png
# Saved extracted_images_for_ocr/page_0324.png
# Saved extracted_images_for_ocr/page_0325.png
# Saved extracted_images_for_ocr/page_0326.png
# Saved extracted_images_for_ocr/page_0327.png
# Saved extracted_images_for_ocr/page_0328.png
# Saved extracted_images_for_ocr/page_0329.png
# Saved extracted_images_for_ocr/page_0330.png
# Saved extracted_images_for_ocr/page_0331.png
# Saved extracted_images_for_ocr/page_0332.png
# Saved extracted_images_for_ocr/page_0333.png
# Saved extracted_images_for_ocr/page_0334.png
# Saved extracted_images_for_ocr/page_0335.png
# Saved extracted_images_for_ocr/page_0336.png
# Saved extracted_images_for_ocr/page_0337.png
# Saved extracted_images_for_ocr/page_0338.png
# Saved extracted_images_for_ocr/page_0339.png
# Saved extracted_images_for_ocr/page_0340.png
# Saved extracted_images_for_ocr/page_0341.png
# Saved extracted_images_for_ocr/page_0342.png
# Saved extracted_images_for_ocr/page_0343.png
# Saved extracted_images_for_ocr/page_0344.png
# Saved extracted_images_for_ocr/page_0345.png
# Saved extracted_images_for_ocr/page_0346.png
# Saved extracted_images_for_ocr/page_0347.png
# Saved extracted_images_for_ocr/page_0348.png
# Saved extracted_images_for_ocr/page_0349.png
# Saved extracted_images_for_ocr/page_0350.png
# Saved extracted_images_for_ocr/page_0351.png
# Saved extracted_images_for_ocr/page_0352.png
# Saved extracted_images_for_ocr/page_0353.png
# Saved extracted_images_for_ocr/page_0354.png
# Saved extracted_images_for_ocr/page_0355.png
# Saved extracted_images_for_ocr/page_0356.png
# Saved extracted_images_for_ocr/page_0357.png
# Saved extracted_images_for_ocr/page_0358.png
# Saved extracted_images_for_ocr/page_0359.png
# Saved extracted_images_for_ocr/page_0360.png
# Saved extracted_images_for_ocr/page_0361.png
# Saved extracted_images_for_ocr/page_0362.png
# Saved extracted_images_for_ocr/page_0363.png
# Saved extracted_images_for_ocr/page_0364.png
# Saved extracted_images_for_ocr/page_0365.png
# Saved extracted_images_for_ocr/page_0366.png
# Saved extracted_images_for_ocr/page_0367.png
# Saved extracted_images_for_ocr/page_0368.png
# Saved extracted_images_for_ocr/page_0369.png
# Saved extracted_images_for_ocr/page_0370.png
# Saved extracted_images_for_ocr/page_0371.png
# Saved extracted_images_for_ocr/page_0372.png
# Saved extracted_images_for_ocr/page_0373.png
# Saved extracted_images_for_ocr/page_0374.png
# Saved extracted_images_for_ocr/page_0375.png
# Saved extracted_images_for_ocr/page_0376.png
# Saved extracted_images_for_ocr/page_0377.png
# Saved extracted_images_for_ocr/page_0378.png
# Saved extracted_images_for_ocr/page_0379.png
# Saved extracted_images_for_ocr/page_0380.png
# Saved extracted_images_for_ocr/page_0381.png
# Saved extracted_images_for_ocr/page_0382.png
# Saved extracted_images_for_ocr/page_0383.png
# Saved extracted_images_for_ocr/page_0384.png
# Saved extracted_images_for_ocr/page_0385.png
# Saved extracted_images_for_ocr/page_0386.png
# Saved extracted_images_for_ocr/page_0387.png
# Saved extracted_images_for_ocr/page_0388.png
# Saved extracted_images_for_ocr/page_0389.png
# Saved extracted_images_for_ocr/page_0390.png
# Saved extracted_images_for_ocr/page_0391.png
# Saved extracted_images_for_ocr/page_0392.png
# Saved extracted_images_for_ocr/page_0393.png
# Saved extracted_images_for_ocr/page_0394.png
# Saved extracted_images_for_ocr/page_0395.png
# Saved extracted_images_for_ocr/page_0396.png
# Saved extracted_images_for_ocr/page_0397.png
# Saved extracted_images_for_ocr/page_0398.png
# Saved extracted_images_for_ocr/page_0399.png
# Saved extracted_images_for_ocr/page_0400.png
# Saved extracted_images_for_ocr/page_0401.png
# Saved extracted_images_for_ocr/page_0402.png
# Saved extracted_images_for_ocr/page_0403.png
# Saved extracted_images_for_ocr/page_0404.png
# Saved extracted_images_for_ocr/page_0405.png
# Saved extracted_images_for_ocr/page_0406.png
# Saved extracted_images_for_ocr/page_0407.png
# Saved extracted_images_for_ocr/page_0408.png
# Saved extracted_images_for_ocr/page_0409.png
# Saved extracted_images_for_ocr/page_0410.png
# Saved extracted_images_for_ocr/page_0411.png
# Saved extracted_images_for_ocr/page_0412.png
# Saved extracted_images_for_ocr/page_0413.png
# Saved extracted_images_for_ocr/page_0414.png
# Saved extracted_images_for_ocr/page_0415.png
# Saved extracted_images_for_ocr/page_0416.png
# Saved extracted_images_for_ocr/page_0417.png
# Saved extracted_images_for_ocr/page_0418.png
# Saved extracted_images_for_ocr/page_0419.png
# Saved extracted_images_for_ocr/page_0420.png
# Saved extracted_images_for_ocr/page_0421.png
# Saved extracted_images_for_ocr/page_0422.png
# Saved extracted_images_for_ocr/page_0423.png
# Saved extracted_images_for_ocr/page_0424.png
# Saved extracted_images_for_ocr/page_0425.png
# Saved extracted_images_for_ocr/page_0426.png
# Saved extracted_images_for_ocr/page_0427.png
# Saved extracted_images_for_ocr/page_0428.png
# Saved extracted_images_for_ocr/page_0429.png
# Saved extracted_images_for_ocr/page_0430.png
# Saved extracted_images_for_ocr/page_0431.png
# Saved extracted_images_for_ocr/page_0432.png
# Saved extracted_images_for_ocr/page_0433.png
# Saved extracted_images_for_ocr/page_0434.png
# Saved extracted_images_for_ocr/page_0435.png
# Saved extracted_images_for_ocr/page_0436.png
# Saved extracted_images_for_ocr/page_0437.png
# Saved extracted_images_for_ocr/page_0438.png
# Saved extracted_images_for_ocr/page_0439.png
# Saved extracted_images_for_ocr/page_0440.png
# Saved extracted_images_for_ocr/page_0441.png
# Saved extracted_images_for_ocr/page_0442.png
# Saved extracted_images_for_ocr/page_0443.png
# Saved extracted_images_for_ocr/page_0444.png
# Saved extracted_images_for_ocr/page_0445.png
# Saved extracted_images_for_ocr/page_0446.png
# Saved extracted_images_for_ocr/page_0447.png
# Saved extracted_images_for_ocr/page_0448.png
# Saved extracted_images_for_ocr/page_0449.png
# Saved extracted_images_for_ocr/page_0450.png
# Saved extracted_images_for_ocr/page_0451.png
# Saved extracted_images_for_ocr/page_0452.png
# Image extraction complete. Images saved to 'extracted_images_for_ocr' directory.

# %%
# Block 1: Setup, Authentication, and Function Definitions (Run this after PyMuPDF code)

import os
import io
import json
import vertexai
import asyncio
from PIL import Image
# Import necessary Vertex AI libraries
from vertexai.generative_models import GenerativeModel, Part, Image as VertexImage
from vertexai.preview.generative_models import Image as PreviewImage # Fallback

# -----------------------------------------------------------
# --- Configuration Variables: UPDATE THESE ---
# -----------------------------------------------------------

# Path to your uploaded GCP JSON key file
JSON_FILE_PATH = '/content/renaissance-ocr-4aabe5b8dc65.json'

# --- The folder where your images are saved from the previous step: ---
INPUT_IMAGE_FOLDER = 'extracted_images_for_ocr'

# GCP Project Details
PROJECT_ID = 'renaissance-ocr'
LOCATION = 'global'
GEMINI_MODEL = 'gemini-2.5-flash' # Using flash for speed, can change to pro
OUTPUT_TEXT_FILE = 'Extracted_OCR_Text_Spanish_Full_Async.txt'

# Specific prompt tailored for Early Modern Spanish
OCR_PROMPT = """
Eres un corrector experto de textos en español moderno temprano. TU TAREA es corregir ÚNICAMENTE los errores de OCR en el texto de entrada basándose en la imagen proporcionada. No reescribas ni alteres el uso auténtico del período.

REGLAS ESPECÍFICAS PARA ESPAÑOL MODERNO TEMPRANO:
1.  **Preservar el texto original (uso auténtico):** Mantén la redacción, gramática, sintaxis, y la ortografía histórica original. Corrige SOLAMENTE errores evidentes de OCR.
2.  **Normalización mínima:** Mantén el uso original de `u`/`v`, `i`/`j`. Reemplazar `&` con `y`. Asegurar que la `ñ` esté correcta.  ſ = s, ß = ss, ç =z or c
3.  **Desguionizado e Hiphenación:** Elimina todos los guiones de final de línea que unan una palabra partida.
4.  **Formato:** Conserva todas las pausas de párrafo y la capitalización exactamente igual que en la entrada. Elimina mobiliario de página (e.g., "A ij", signaturas).
5.  **Salida:** Produce ÚNICAMENTE el texto en español corregido. NO añadas comentarios, explicaciones, ni formato adicional.
6. **Emimina números de página de OCR** eliminar cualquier mención de números de página de OCR
"""
# -----------------------------------------------------------

# -----------------------------------------------------------
# --- Authenticate and Initialize the Vertex AI Client ---
# -----------------------------------------------------------
try:
    if not os.path.exists(JSON_FILE_PATH):
        raise FileNotFoundError(f"Credentials file not found at: {JSON_FILE_PATH}.")
    os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = JSON_FILE_PATH
    vertexai.init(project=PROJECT_ID, location=LOCATION)
    # Initialize the model globally
    model = GenerativeModel(GEMINI_MODEL)
    print(f"Gemini Model '{GEMINI_MODEL}' initialized successfully for project '{PROJECT_ID}'.")
except Exception as e:
    print(f"Authentication or client initialization failed: {e}")
    exit()

# -----------------------------------------------------------
# --- Define Asynchronous OCR Function ---
# -----------------------------------------------------------

# ASYNC function to call the API
async def process_image_with_gemini_async(image_path):
    """Processes a local image file using the Gemini multimodal model asynchronously."""
    try:
        # Use load_from_file (standard method)
        vertex_ai_image = VertexImage.load_from_file(image_path)
    except Exception as e:
        return f"Error loading image {image_path}: {e}", image_path

    contents = [OCR_PROMPT, vertex_ai_image]

    try:
        # Use generate_content_async for non-blocking API calls
        response = await model.generate_content_async(contents)
        full_text = response.text or ""
        if full_text:
            return full_text, image_path
        else:
            return "No text detected", image_path
    except Exception as e:
        return f"API call failed for {image_path}: {e}", image_path
# Out:
# Found 452 previously completed images in Extracted_OCR_Text_Spanish_Full_Async.txt. Resuming pipeline.
# All images already processed successfully. No new tasks to run.

# %%
import os
import asyncio
# Assuming GEMINI_MODEL, INPUT_IMAGE_FOLDER, OUTPUT_TEXT_FILE,
# and process_image_with_gemini_async are defined in previous cells/blocks.

# Define the specific output file name you provided in your prompt
# This ensures we check the correct file for existing content
OUTPUT_TEXT_FILE = 'Extracted_OCR_Text_Spanish_Full_Async.txt'

async def main_async_pipeline_resume_from_images():

    # 1. Identify which images need processing
    image_files_list = sorted([
        os.path.join(INPUT_IMAGE_FOLDER, f)
        for f in os.listdir(INPUT_IMAGE_FOLDER)
        if f.endswith('.png') or f.endswith('.jpeg')
    ])

    if not image_files_list:
        print(f"Pipeline halted. No images found in '{INPUT_IMAGE_FOLDER}'.")
        return

    # 2. Check existing output file for completed pages
    completed_images = set()
    if os.path.exists(OUTPUT_TEXT_FILE):
        with open(OUTPUT_TEXT_FILE, 'r', encoding='utf-8') as f_out:
            content = f_out.read()
            # Simple check: find all filenames already marked as 'Start of OCR from <filename>'
            import re
            matches = re.findall(r"--- Start of OCR from (page_\d{4}\.png) ---", content)
            completed_images = set(matches)
        print(f"Found {len(completed_images)} previously completed images in {OUTPUT_TEXT_FILE}. Resuming pipeline.")
    else:
        # Create a new file if it doesn't exist to ensure the script can run
        with open(OUTPUT_TEXT_FILE, 'w', encoding='utf-8') as f:
            f.write(f"Gemini OCR Results [ASYNC PROCESSING] - Initializing new run.\n" + "=" * 60 + "\n")
        print(f"No existing file found. Starting a fresh OCR run.")

    # 3. Filter the list to only images that haven't been completed
    images_to_process = [
        img_path for img_path in image_files_list
        if os.path.basename(img_path) not in completed_images
    ]

    if not images_to_process:
        print("All images already processed successfully. No new tasks to run.")
        return

    print(f"\nStarting ASYNC Gemini OCR process for {len(images_to_process)} remaining images using {GEMINI_MODEL}...")

    # Create tasks only for the *remaining* images
    tasks = [process_image_with_gemini_async(image_path) for image_path in images_to_process]

    # Run remaining tasks concurrently
    try:
        results = await asyncio.gather(*tasks)
    except Exception as e:
        print(f"\nAn error occurred during an async task: {e}")
        print("The pipeline stopped prematurely. You can run this cell again to resume from the last completed page.")
        # We handle the potential failure here, and the results list might be incomplete.

        # To save partial results obtained so far, we need a way to access them,
        # but asyncio.gather stops everything on the first exception.
        # A more robust approach uses asyncio.as_completed or individual try/excepts within the task function.
        return


    # 4. Append new results to the existing file in order
    print(f"\n--- Appending New Gemini OCR Results ---")

    # results is a list of (text, image_path) for *newly* completed items
    # We still sort them just in case they were processed out of order in the gather call
    sorted_new_results = sorted(results, key=lambda x: x[1])

    with open(OUTPUT_TEXT_FILE, 'a', encoding='utf-8') as f_out:
        for text, image_path in sorted_new_results:
            section_text = f"\n\n--- Start of OCR from {os.path.basename(image_path)} ---\n\n{text}\n\n--- End of OCR from {os.path.basename(image_path)} ---\n\n"
            f_out.write(section_text)
            print(f"  -> Appended results for {os.path.basename(image_path)}")

    print(f"\nAll newly extracted text has been appended to: {OUTPUT_TEXT_FILE}")
    print(f"Total images processed so far: {len(image_files_list)}")


# Execute the new async main function in the notebook environment
await main_async_pipeline_resume_from_images()
# Out:
# Found 452 previously completed images in Extracted_OCR_Text_Spanish_Full_Async.txt. Resuming pipeline.
# All images already processed successfully. No new tasks to run.

# %% [markdown]
# There are missing images, so need to make more robust

# %%
# !pip install tenacity
# Out:
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (9.1.2)

# %%
import os
import asyncio
import re
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type
from google.api_core.exceptions import ResourceExhausted, ServiceUnavailable, InternalServerError
# Ensure all previous imports (like VertexImage, OCR_PROMPT, etc.) from Block 1 are still available

# --- Configuration for Resilience ---
MAX_CONCURRENT_REQUESTS = 5
RETRYABLE_EXCEPTIONS = (ResourceExhausted, ServiceUnavailable, InternalServerError)
semaphore = asyncio.Semaphore(MAX_CONCURRENT_REQUESTS)
# -----------------------------------

@retry(
    wait=wait_exponential(multiplier=1, min=4, max=60),
    stop=stop_after_attempt(5),
    retry=retry_if_exception_type(RETRYABLE_EXCEPTIONS),
    reraise=True
)
async def process_image_with_gemini_async_robust(image_path):
    async with semaphore:
        try:
            vertex_ai_image = VertexImage.load_from_file(image_path)
            contents = [OCR_PROMPT, vertex_ai_image]
            response = await model.generate_content_async(contents)
            full_text = response.text or ""
            # Return both the text and the path for later sorting
            return full_text, image_path
        except Exception as e:
            print(f"-> Attempt failed for {os.path.basename(image_path)}: {e}")
            raise


async def main_async_pipeline_rerun_all_ordered():
    # 1. Collect all images in sorted order
    image_files_list = sorted([
        os.path.join(INPUT_IMAGE_FOLDER, f)
        for f in os.listdir(INPUT_IMAGE_FOLDER)
        if f.endswith('.png') or f.endswith('.jpeg')
    ])

    if not image_files_list:
        print(f"Pipeline halted. No images found in '{INPUT_IMAGE_FOLDER}'.")
        return

    # 2. Force a fresh start by deleting the old file
    if os.path.exists(OUTPUT_TEXT_FILE):
        os.remove(OUTPUT_TEXT_FILE)
        print(f"Deleted existing output file '{OUTPUT_TEXT_FILE}' to force a full rerun.")

    print(f"\nStarting ASYNC Gemini OCR process for ALL {len(image_files_list)} images (Results will be stored in memory first)...")

    # 3. Create all tasks
    tasks = [process_image_with_gemini_async_robust(image_path) for image_path in image_files_list]

    # 4. Run tasks concurrently using asyncio.gather()
    # Note: If any single task fails permanently after retries, the whole gather fails.
    try:
        # results will be a list of tuples (text, image_path)
        results = await asyncio.gather(*tasks)
        print(f"\n--- All {len(results)} images processed successfully. Sorting and saving... ---")
    except Exception as e:
        print(f"\nFATAL PIPELINE ERROR: A permanent error occurred in one or more tasks after all retries. Error: {e}")
        print("The pipeline stopped before all tasks finished. The output file was not generated in full.")
        return

    # 5. Sort the results list by the image path (which contains the page number 0001.png, etc.)
    # The key sorts by the second element in the tuple (the file path string)
    sorted_results = sorted(results, key=lambda x: x[1])

    # 6. Write ALL sorted results to the output file in a single synchronous operation
    with open(OUTPUT_TEXT_FILE, 'w', encoding='utf-8') as f_out:
        header = f"Gemini OCR Results for the full document ({len(sorted_results)} pages) [ASYNC PROCESSING - ORDERED OUTPUT]\n" + "=" * 60 + "\n"
        f_out.write(header)

        for text, image_path in sorted_results:
            section_text = f"\n\n--- Start of OCR from {os.path.basename(image_path)} ---\n\n{text}\n\n--- End of OCR from {os.path.basename(image_path)} ---\n\n"
            f_out.write(section_text)

    print(f"\n--- Processing Summary ---")
    print(f"Total tasks attempted and saved: {len(image_files_list)}")
    print(f"All extracted text has been saved sequentially to: {OUTPUT_TEXT_FILE}")


# Execute the main function to rerun all images
await main_async_pipeline_rerun_all_ordered()
# Out:
# Deleted existing output file 'Extracted_OCR_Text_Spanish_Full_Async.txt' to force a full rerun.
#
# Starting ASYNC Gemini OCR process for ALL 452 images (Results will be stored in memory first)...
# -> Attempt failed for page_0020.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0260.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0001.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0021.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0406.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0203.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0154.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0156.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0155.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0162.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0163.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0164.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0149.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0282.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0150.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0166.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0351.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0180.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0182.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0183.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0181.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0186.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0151.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0068.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0048.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0153.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0206.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0049.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0098.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0099.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0360.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0222.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0090.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0223.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0225.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0224.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0228.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0229.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0227.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0294.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0238.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0365.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0366.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0225.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0246.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0299.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0257.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0300.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0266.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0231.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0270.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0232.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0183.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0055.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0158.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0218.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0278.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0217.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0106.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0108.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0291.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0295.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0071.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0072.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0301.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0302.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0303.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0314.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0239.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0314.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0111.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0317.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0318.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0319.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0322.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0160.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0321.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0320.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0332.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0060.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0085.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0342.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0353.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0363.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0365.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0368.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0281.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0176.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0445.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# -> Attempt failed for page_0447.png: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# /tmp/ipython-input-359808689.py in <cell line: 1>()
#      84
#      85 # Execute the main function to rerun all images
# ---> 86 await main_async_pipeline_rerun_all_ordered()
#
# /tmp/ipython-input-359808689.py in main_async_pipeline_rerun_all_ordered()
#      58     try:
#      59         # results will be a list of tuples (text, image_path)
# ---> 60         results = await asyncio.gather(*tasks)
#      61         print(f"\n--- All {len(results)} images processed successfully. Sorting and saving... ---")
#      62     except Exception as e:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in async_wrapped(*args, **kwargs)
#     187             copy = self.copy()
#     188             async_wrapped.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 189             return await copy(fn, *args, **kwargs)
#     190
#     191         # Preserve attributes
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     109         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     110         while True:
# --> 111             do = await self.iter(retry_state=retry_state)
#     112             if isinstance(do, DoAttempt):
#     113                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in iter(self, retry_state)
#     151         result = None
#     152         for action in self.iter_state.actions:
# --> 153             result = await action(retry_state)
#     154         return result
#     155
#
# /usr/local/lib/python3.12/dist-packages/tenacity/_utils.py in inner(*args, **kwargs)
#      97
#      98     async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99         return call(*args, **kwargs)
#     100
#     101     return inner
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     398     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400             self._add_action_func(lambda rs: rs.outcome.result())
#     401             return
#     402
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/asyncio/__init__.py in __call__(self, fn, *args, **kwargs)
#     112             if isinstance(do, DoAttempt):
#     113                 try:
# --> 114                     result = await fn(*args, **kwargs)
#     115                 except BaseException:  # noqa: B902
#     116                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /tmp/ipython-input-359808689.py in process_image_with_gemini_async_robust(image_path)
#      19 )
#      20 async def process_image_with_gemini_async_robust(image_path):
# ---> 21     async with semaphore:
#      22         try:
#      23             vertex_ai_image = VertexImage.load_from_file(image_path)
#
# /usr/lib/python3.12/asyncio/locks.py in __aenter__(self)
#      12 class _ContextManagerMixin:
#      13     async def __aenter__(self):
# ---> 14         await self.acquire()
#      15         # We have no use for the "as ..."  clause in the with
#      16         # statement for locks.
#
# /usr/lib/python3.12/asyncio/locks.py in acquire(self)
#     384         try:
#     385             try:
# --> 386                 await fut
#     387             finally:
#     388                 self._waiters.remove(fut)
#
# CancelledError:

# %% [markdown]
# This doesn't seem to work well with the API breaking down. so let's do vision ocr, then polish text.

# %%
# --- IMPORTS AND CONFIGURATION (Corrected) ---
import os
import io
import json
import vertexai
import asyncio
import re
# Make sure these are installed: !pip install --upgrade google-cloud-vision vertexai google-cloud tenacity
from google.cloud import vision
from vertexai.generative_models import GenerativeModel, Part, Image as VertexImage
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type
from google.api_core.exceptions import ResourceExhausted, ServiceUnavailable, InternalServerError

# --- Configuration Variables: UPDATE THESE ---
JSON_FILE_PATH = '/content/renaissance-ocr-4aabe5b8dc65.json'
INPUT_IMAGE_FOLDER = 'extracted_images_for_ocr'
PROJECT_ID = 'renaissance-ocr'

# !! FIX 1: Changed 'global' to a valid region like 'us-central1' !!
LOCATION = 'us-central1'

GEMINI_MODEL = 'gemini-2.5-flash'
OUTPUT_TEXT_FILE = 'Extracted_OCR_Text_Spanish_Full_Async_Vision_Polished.txt'

# Polishing Prompt for Gemini
OCR_PROMPT = """
You are an expert text corrector in early modern Spanish. YOUR TASK is to correct ONLY OCR errors in the input text based on the provided image. Do not rewrite or alter the authentic use of the period.

SPECIFIC RULES FOR EARLY MODERN SPANISH:
1.  **Preserve the original text (authentic use):** Maintain the original wording, grammar, syntax, and historical spelling. Correct ONLY obvious OCR errors.
2.  **Minimum normalization:** Maintain the original use of `u`/`v`, `i`/`j`. Replace `&` with `y`. Ensure that `ñ` is correct. ſ = s, ß = ss, ç = z or c
3.  **Dehyphenation and Hyphenation:** Remove all end-of-line hyphens that join a split word.
4.  **Formatting:** Preserve all paragraph breaks and capitalization exactly as in the input. Remove page furniture (e.g., "A ij", signatures).
5.  **Output:** Produce ONLY the corrected Spanish text. DO NOT add comments, explanations, or additional formatting.
6. **Remove OCR page numbers** remove any mention of OCR page numbers
"""
# --- Resilience Configuration ---
MAX_CONCURRENT_REQUESTS = 5
RETRYABLE_EXCEPTIONS = (ResourceExhausted, ServiceUnavailable, InternalServerError)
semaphore = asyncio.Semaphore(MAX_CONCURRENT_REQUESTS)

# --- Authentication and Client Initialization ---
try:
    if not os.path.exists(JSON_FILE_PATH):
        raise FileNotFoundError(f"Credentials file not found at: {JSON_FILE_PATH}.")
    os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = JSON_FILE_PATH

    # Initialize Vertex AI with the corrected region
    vertexai.init(project=PROJECT_ID, location=LOCATION)

    model = GenerativeModel(GEMINI_MODEL)
    vision_client = vision.ImageAnnotatorClient() # This line should now run successfully
    print(f"Gemini and Cloud Vision clients initialized correctly for region: {LOCATION}.")
except Exception as e:
    print(f"Authentication or client initialization failed: {e}")
    exit()

# --- Definition of Processing Functions ---
def run_vision_ocr(image_path):
    """Runs OCR from Document with Google Cloud Vision (synchronous)."""
    # FIX 2: The vision_client is now defined globally and accessible here
    with io.open(image_path, 'rb') as image_file:
        content = image_file.read()
    image = vision.Image(content=content)
    response = vision_client.document_text_detection(image=image)
    if response.error.message:
        raise Exception(f"Vision API Error: {response.error.message}")
    return response.full_text_annotation.text

@retry(
    wait=wait_exponential(multiplier=1, min=4, max=60),
    stop=stop_after_attempt(5),
    retry=retry_if_exception_type(RETRYABLE_EXCEPTIONS),
    reraise=True
)
async def polish_text_with_gemini_async(image_path, initial_ocr_text):
    """Polishes the initial text from Vision using Gemini and the specific prompt."""
    async with semaphore:
        try:
            vertex_ai_image = VertexImage.load_from_file(image_path)
            contents = [
                OCR_PROMPT,
                f"\n\nINPUT TEXT (from Google Vision):\n{initial_ocr_text}\n\n",
                vertex_ai_image
            ]
            response = await model.generate_content_async(contents)
            return response.text or "", image_path
        except Exception as e:
            print(f"-> Gemini polishing attempt failed for {os.path.basename(image_path)}: {e}")
            raise

# --- MAIN EXECUTION PIPELINE FUNCTION ---

async def main_async_pipeline_vision_polish_ordered():
    image_files_list = sorted([
        os.path.join(INPUT_IMAGE_FOLDER, f)
        for f in os.listdir(INPUT_IMAGE_FOLDER)
        if f.endswith('.png') or f.endswith('.jpeg')
    ])

    if not image_files_list:
        print(f"Pipeline stopped. No images found in '{INPUT_IMAGE_FOLDER}'.")
        return

    if os.path.exists(OUTPUT_TEXT_FILE):
        os.remove(OUTPUT_TEXT_FILE)
        print(f"Existing output file '{OUTPUT_TEXT_FILE}' was deleted to force a full run.")

    print(f"\nStarting the two-phase OCR process for {len(image_files_list)} images.")

    print("Running Google Vision OCR on all images...")
    vision_results = {}
    for image_path in image_files_list:
        try:
            # This function now correctly accesses the global vision_client
            vision_text = run_vision_ocr(image_path)
            vision_results[image_path] = vision_text
        except Exception as e:
            print(f"Fatal Google Vision error in {os.path.basename(image_path)}: {e}")
            return

    print(f"\nStarting ASYNCHRONOUS polishing phase with Gemini using {GEMINI_MODEL}...")
    tasks = [
        polish_text_with_gemini_async(image_path, text)
        for image_path, text in vision_results.items()
    ]

    try:
        polished_results = await asyncio.gather(*tasks)
        print(f"\n--- All images polished successfully. Ordering and saving... ---")
    except Exception as e:
        print(f"\nFATAL ERROR IN PIPELINE: A permanent error occurred during Gemini polishing after retries. Error: {e}")
        return

    sorted_polished_results = sorted(polished_results, key=lambda x: x)

    with open(OUTPUT_TEXT_FILE, 'w', encoding='utf-8') as f_out:
        header = f"Gemini Polished OCR Results ({len(sorted_polished_results)} pages) [VISION+GEMINI ORDERED OUTPUT]\n" + "=" * 80 + "\n"
        f_out.write(header)

        for text, image_path in sorted_polished_results:
            section_text = f"\n\n--- Start of OCR from {os.path.basename(image_path)} ---\n\n{text}\n\n--- End of OCR from {os.path.basename(image_path)} ---\n\n"
            f_out.write(section_text)

    print(f"\n--- Process Summary ---")
    print(f"Total images processed and saved: {len(image_files_list)}")
    print(f"All extracted text has been saved sequentially in: {OUTPUT_TEXT_FILE}")


# --- Execute the main function ---
await main_async_pipeline_vision_polish_ordered()
# Out:
# Gemini and Cloud Vision clients initialized correctly for region: us-central1.
#
# Starting the two-phase OCR process for 452 images.
# Running Google Vision OCR on all images...
#
# Starting ASYNCHRONOUS polishing phase with Gemini using gemini-2.5-flash...
#
# --- All images polished successfully. Ordering and saving... ---
#
# --- Process Summary ---
# Total images processed and saved: 452
# All extracted text has been saved sequentially in: Extracted_OCR_Text_Spanish_Full_Async_Vision_Polished.txt
